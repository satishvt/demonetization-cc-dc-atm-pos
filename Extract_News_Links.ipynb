# %% [markdown]
# # News Paper Sentiment Analysis
#
# #### Step 1 : Data Collection - Stage 1 - Extract Links
# >
# > + Extract the news links on 4 major news sites using Google
#
# #### Step 2 : Data Collection - Stage 2 - Download content from links
# >
# > + Extract the news links on 4 major news sites using Google
#
# #### Step 3 : Data Collection - Stage 3 - Merge content from links
# >
# > + All the content, publish dates was merged to one single excel document
#
# #### Step 4 : Data Processing - Cleansing
# >
# > + Cleanse the data (removing special characters, lemmatization etc.)
#
# #### Step 5 : Execute Sentiment Analysis
# > + Sentiment analysis was performed on the cleansed data, to classify if each of the document (news paper content) is positive, neutral or negative sentiment
#
# #### Step 6: Analysis 1: Sentiment swings from Nov-2016 till Mar-2018
# > + Summarize the sentiment by month
#
# #### Step 7 : Wordcloud & Frequency distribution of the overall newspaper text corpus
# > + Overall corpus was split into training and test data. Wordcloud showed some code syntax to be present, which was cleansed.
# > + Wordcloud was generated on the overall text corpus
# > + Frequency distribution of overall words in the text corpus was generated

# %% [markdown]
# ## Stage 1 of Data Collection:

# %% [markdown]
# ### Requirement: Newspaper/News sites Sentiment Analysis on Demonetization

# %% [markdown]
# #### Methodology
# > + Total of 4 Famous Newspapers/Web news channels were chosen
# >
# > + Google search for demonetization in the URLs of the news paper sites was performed
# >
# > + Good results was scrapped to extract out the links of the news links, from which the data has to be extracted
# >
# > + News Sites chosen: The Hindu, Business Standard, First Post, Times of India

# %% [markdown]
# #### Technical Approach

# %% [markdown]
# > + For every news paper site, a folder was created which consists of news paper content text from each link (it was numbered)
# >
# > + The link number and the link was maintained in a seperate excel sheet for each news paper

# %% [markdown]
# ### Constants & Imports

# %%
### Constants & Imports
import bs4
from bs4 import BeautifulSoup
import requests
import urllib
import urllib3
import re
import os

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.79 Safari/537.36'}
for results in google.search("demonetization inurl:thehindu.com",1):
    print(results.link)
    #t = requests.post(results.link)
    #t1 = BeautifulSoup(t.content.lower(),"lxml").find_all("a",href=re.compile(".XLS",re.IGNORECASE))

# %%
## Credits: http://edmundmartin.com/scraping-google-with-python/

import requests
from bs4 import BeautifulSoup


USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}


def fetch_results(search_term, number_results, language_code):
    assert isinstance(search_term, str), 'Search term must be a string'
    assert isinstance(number_results, int), 'Number of results must be an integer'
    escaped_search_term = search_term.replace(' ', '+')

    google_url = 'https://www.google.com/search?q={}&num={}&hl={}'.format(escaped_search_term, number_results, language_code)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()

    return search_term, response.text

def parse_results(html):
    soup = BeautifulSoup(html, 'html.parser')

    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
        if link:
            link = link['href']
            if link != '#':
                found_results.append({'link': link})
    return found_results

if __name__ == '__main__':
    results=[]
    keyword, html = fetch_results('demonetization inurl:thehindu.com', 100, 'en')
    results = parse_results(html)
    for link in results:
        print(link['link'])
# Out:
# http://www.thehindu.com/topic/demonetisation/
# http://www.thehindu.com/opinion/lead/the-great-reset-a-year-later/article20005359.ece
# http://www.thehindu.com/opinion/op-ed/demonetisation-now-a-proven-failure/article19638198.ece
# http://www.thehindu.com/business/what-demonetisation-did-to-tax-collections/article23550004.ece
# http://www.thehindu.com/opinion/op-ed/discordant-notes/article19999299.ece
# http://www.thehindu.com/opinion/op-ed/after-demonetisation/article19595586.ece
# http://www.thehindu.com/business/Economy/only-12-of-demonetised-1000-notes-did-not-return-rbi/article19590311.ece
# http://www.thehindu.com/opinion/op-ed/Demonetisation-is-for-the-long-run/article16773642.ece
# http://www.thehindu.com/opinion/editorial/shifting-goal-posts/article19595787.ece
# http://www.thehindu.com/elections/gujarat-2017/demonetisation-was-a-black-day-for-our-economy-democracy-manmohan-singh/article19996574.ece
# http://www.thehindu.com/opinion/op-ed/on-the-margins/article19993587.ece
# ...

# %%
## Credits: http://edmundmartin.com/scraping-google-with-python/

import requests
from bs4 import BeautifulSoup


USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}


def fetch_results(search_term, number_results, language_code):
    assert isinstance(search_term, str), 'Search term must be a string'
    assert isinstance(number_results, int), 'Number of results must be an integer'
    escaped_search_term = search_term.replace(' ', '+')

    google_url = 'https://www.google.com/search?q={}&num={}&hl={}'.format(escaped_search_term, number_results, language_code)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()

    return search_term, response.text

def parse_results(html):
    soup = BeautifulSoup(html, 'html.parser')

    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
        if link:
            link = link['href']
            if link != '#':
                found_results.append({'link': link})
    return found_results

if __name__ == '__main__':
    results=[]
    keyword, html = fetch_results('demonetization inurl:timesofindia.indiatimes.com', 100, 'en')
    results = parse_results(html)
    for link in results:
        print(link['link'])
# Out:
# https://timesofindia.indiatimes.com/topic/Demonetisation
# https://timesofindia.indiatimes.com/business/india-business/a-year-after-demonetisation-hunt-for-black-money-getting-more-intense/articleshow/61523436.cms
# https://timesofindia.indiatimes.com/business/india-business/post-demonetisation-99-of-rs-1000-notes-back-with-rbi/articleshow/60239637.cms
# https://timesofindia.indiatimes.com/india/demonetisation-success-explained-in-numbers/articleshow/60310546.cms
# https://timesofindia.indiatimes.com/india/a-year-after-demonetisation-seizures-of-fake-notes-see-sharp-dip/articleshow/61538303.cms
# https://blogs.timesofindia.indiatimes.com/emphasis/who-advised-demonetisation-2/
# https://timesofindia.indiatimes.com/india/heres-how-rahul-gandhi-would-have-rolled-out-demonetisation/articleshow/63245284.cms
# https://timesofindia.indiatimes.com/business/india-business/warned-government-about-cost-of-demonetisation-former-rbi-governor-raghuram-rajan-says/articleshow/60343662.cms
# ...

# %%
## Credits: http://edmundmartin.com/scraping-google-with-python/

import requests
from bs4 import BeautifulSoup


USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}


def fetch_results(search_term, number_results, language_code):
    assert isinstance(search_term, str), 'Search term must be a string'
    assert isinstance(number_results, int), 'Number of results must be an integer'
    escaped_search_term = search_term.replace(' ', '+')

    google_url = 'https://www.google.com/search?q={}&num={}&hl={}'.format(escaped_search_term, number_results, language_code)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()

    return search_term, response.text

def parse_results(html):
    soup = BeautifulSoup(html, 'html.parser')

    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
        if link:
            link = link['href']
            if link != '#':
                found_results.append({'link': link})
    return found_results

if __name__ == '__main__':
    results=[]
    keyword, html = fetch_results('demonetization inurl
# ...

# %%
## Credits: http://edmundmartin.com/scraping-google-with-python/

import requests
from bs4 import BeautifulSoup


USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}


def fetch_results(search_term, number_results, language_code):
    assert isinstance(search_term, str), 'Search term must be a string'
    assert isinstance(number_results, int), 'Number of results must be an integer'
    escaped_search_term = search_term.replace(' ', '+')

    google_url = 'https://www.google.com/search?q={}&num={}&hl={}'.format(escaped_search_term, number_results, language_code)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()

    return search_term, response.text

def parse_results(html):
    soup = BeautifulSoup(html, 'html.parser')

    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
        if link:
            link = link['href']
            if link != '#':
                found_results.append({'link': link})
    return found_results

if __name__ == '__main__':
    results=[]
    keyword, html = fetch_results('demonetization opinion inurl:firstpost.com', 100, 'en')
    results = parse_results(html)
    for link in results:
        print(link['link'])
# Out:
# https://www.firstpost.com/business/demonetisation-rbi-says-99-banned-notes-are-back-where-is-the-black-money-3991829.html
# https://www.firstpost.com/business/demonetisation-anniversary-public-support-for-note-ban-comes-crashing-down-in-absence-of-concrete-outcomes-4199297.html
# https://www.firstpost.com/india/i-could-not-find-a-single-person-against-demonetisation-i-got-flak-for-saying-this-jay-panda-4203833.html
# https://www.firstpost.com/tag/demonetization
# https://www.firstpost.com/politics/armchair-gst-demonetisation-criticism-isnt-the-worry-narendra-modi-needs-holding-strategy-till-2019-4155633.html
# https://www.firstpost.com/politics/demonetisation-effect-have-patience-major-moves-dont-show-immediate-results-3163964.html
# https://www.firstpost.com/business/demonetisation-will-go-down-in-history-as-one-of-most-reactionary-and-illogical-policy-ever-4199273.html
# https://www.firstpost.com/tag/demonitisation
# ...

# %%
## Credits: http://edmundmartin.com/scraping-google-with-python/

import requests
from bs4 import BeautifulSoup


USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}


def fetch_results(search_term, number_results, language_code):
    assert isinstance(search_term, str), 'Search term must be a string'
    assert isinstance(number_results, int), 'Number of results must be an integer'
    escaped_search_term = search_term.replace(' ', '+')

    google_url = 'https://www.google.com/search?q={}&num={}&hl={}'.format(escaped_search_term, number_results, language_code)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()

    return search_term, response.text

def parse_results(html):
    soup = BeautifulSoup(html, 'html.parser')

    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
        if link:
            link = link['href']
            if link != '#':
                found_results.append({'link': link})
    return found_results

if __name__ == '__main__':
    results=[]
    keyword, html = fetch_results('demonetization inurl:indiatoday.intoday.in', 100, 'en')
    results = parse_results(html)
    for link in results:
        print(link['link'])
# Out:
# http://indiatoday.intoday.in/education/story/one-year-since-demonetisation-note-ban/1/1085167.html
# http://indiatoday.intoday.in/story/demonetisation-note-ban-reserve-bank-of-india-rbi-report/1/1037805.html
# http://indiatoday.intoday.in/story/narendra-modi-demonetisation-income-tax-revenue-digital-economy/1/962380.html
# http://indiatoday.intoday.in/story/demonitisation-note-ban-bjp-modi-economy-arun-jaitley-gdp/1/1080524.html
# http://indiatoday.intoday.in/education/story/demonetization-gst-slowed-down-gdp-growth-of-india/1/1124973.html
# http://indiatoday.intoday.in/story/demonetisation-foolish-decision-by-narendra-modi-govt-says-chidambaram/1/1083517.html
# http://indiatoday.intoday.in/story/demonetisation-pm-modi-nia-seized-old-notes-after-one-year/1/1086805.html
# http://indiatoday.intoday.in/story/demonetisation-good-bad-impact-note-ban/1/822523.html
# http://indiatoday.intoday.in/education/story/demonetisation/1/845657.html
# ...

# %%
## Credits: http://edmundmartin.com/scraping-google-with-python/

import requests
from bs4 import BeautifulSoup


USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}


def fetch_results(search_term, number_results, language_code):
    assert isinstance(search_term, str), 'Search term must be a string'
    assert isinstance(number_results, int), 'Number of results must be an integer'
    escaped_search_term = search_term.replace(' ', '+')

    google_url = 'https://www.google.com/search?q={}&num={}&hl={}'.format(escaped_search_term, number_results, language_code)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()

    return search_term, response.text

def parse_results(html):
    soup = BeautifulSoup(html, 'html.parser')

    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
        if link:
            link = link['href']
            if link != '#':
                found_results.append({'link': link})
    return found_results

if __name__ == '__main__':
    results=[]
    keyword, html = fetch_results('demonetization inurl:dnaindia.com', 100, 'en')
    results = parse_results(html)
    for link in results:
        print(link['link'])
# Out:
# http://www.dnaindia.com/topic/demonetization
# http://www.dnaindia.com/analysis/column-demonetization-a-big-boon-2618497
# http://www.dnaindia.com/business/report-365-days-of-demonetization-after-a-year-top-level-bankers-acknowledge-note-ban-has-done-good-for-the-sector-2558351
# http://www.dnaindia.com/business/report-banks-recorded-480-jump-in-suspicious-transactions-post-demonetization-report-2607243
# http://www.dnaindia.com/india/report-watch-ex-serviceman-who-became-face-of-opp-s-demonetization-protests-supports-note-ban-2558597
# http://www.dnaindia.com/analysis/column-demonetization-debate-antidote-to-corruption-writes-ravi-shankar-prasad-2558407
# /search?q=demonetization+inurl:dnaindia.com&num=100&hl=en&tbm=isch&tbo=u&source=univ&sa=X&ved=0ahUKEwjwrs3g3uHbAhVXA4gKHYWDBWwQsAQISw
# http://www.dnaindia.com/business/report-demonetization-quick-look-at-4-latest-announcements-from-govt-rbi-2287440
# ...
